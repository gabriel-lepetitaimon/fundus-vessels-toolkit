# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from torch_geometric.loader import DataLoader

from fundus_vessels_toolkit.segment_to_graph.models.dataset import VBranchDigraphDataset

# %%
PATH = Path("/run/media/gaby/GREY SSD/PostDoc/DATA/Fundus/Fundus-AV/")
RAW = PATH / "1-images"
GRAPH = PATH / "2-av-graph_CLEM"
TOPO = PATH / "3-topo"

# %%
dataset = VBranchDigraphDataset.load_from_dirs(RAW, TOPO, graph_dir=GRAPH)
# Out:
# Loading 100 branch digraphs...
# /home/gaby/Lab/Src/fundus-vessels-toolkit/src/fundus_vessels_toolkit/vascular_data_objects/vgraph.py:529: UserWarning: The geometric data contains duplicated nodes coordinates.
#   self.check_integrity()
# Rasterizing target topologies...:  24%|██▍       | 24/100 [00:06<00:18,  4.21it/s]/home/gaby/Lab/Src/fundus-vessels-toolkit/src/fundus_vessels_toolkit/vascular_data_objects/vgraph.py:529: UserWarning: The geometric data contains duplicated nodes coordinates.
#   self.check_integrity()
# /home/gaby/Lab/Src/fundus-vessels-toolkit/src/fundus_vessels_toolkit/vascular_data_objects/vgraph.py:529: UserWarning: The geometric data contains duplicated nodes coordinates.
#   self.check_integrity()
# Rasterizing target topologies...:  38%|███▊      | 38/100 [00:10<00:18,  3.32it/s]/home/gaby/Lab/Src/fundus-vessels-toolkit/src/fundus_vessels_toolkit/vascular_data_objects/vgraph.py:529: UserWarning: The geometric data contains duplicated nodes coordinates.
#   self.check_integrity()
# Rasterizing target topologies...: 100%|██████████| 100/100 [00:22<00:00,  4.43it/s]

# %%
dataloader = DataLoader(dataset, batch_size=4)

# %%
# %timeit for data in dataloader: continue
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'for data in dataloader: continue')
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/IPython/core/magics/execution.py:1226, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1224 for index in range(0, 10):
#    1225     number = 10 ** index
# -> 1226     time_number = timer.timeit(number)
#    1227     if time_number >= 0.2:
#    1228         break
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/IPython/core/magics/execution.py:184, in Timer.timeit(self, number)
#     182 gc.disable()
#     183 try:
# --> 184     timing = self.inner(it, self.timer)
#     185 finally:
#     186     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch/utils/data/dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch_geometric/loader/dataloader.py:27, in Collater.__call__(self, batch)
#      25 elem = batch[0]
#      26 if isinstance(elem, BaseData):
# ---> 27     return Batch.from_data_list(
#      28         batch,
#      29         follow_batch=self.follow_batch,
#      30         exclude_keys=self.exclude_keys,
#      31     )
#      32 elif isinstance(elem, torch.Tensor):
#      33     return default_collate(batch)
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch_geometric/data/batch.py:97, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      82 @classmethod
#      83 def from_data_list(
#      84     cls,
#    (...)     87     exclude_keys: Optional[List[str]] = None,
#      88 ) -> Self:
#      89     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      90     list of :class:`~torch_geometric.data.Data` or
#      91     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)     95     Will exclude any keys given in :obj:`exclude_keys`.
#      96     """
# ---> 97     batch, slice_dict, inc_dict = collate(
#      98         cls,
#      99         data_list=data_list,
#     100         increment=True,
#     101         add_batch=not isinstance(data_list[0], Batch),
#     102         follow_batch=follow_batch,
#     103         exclude_keys=exclude_keys,
#     104     )
#     106     batch._num_graphs = len(data_list)  # type: ignore
#     107     batch._slice_dict = slice_dict  # type: ignore
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch_geometric/data/collate.py:109, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     106     continue
#     108 # Collate attributes into a unified representation:
# --> 109 value, slices, incs = _collate(attr, values, data_list, stores,
#     110                                increment)
#     112 # If parts of the data are already on GPU, make sure that auxiliary
#     113 # data like `batch` or `ptr` are also created on GPU:
#     114 if isinstance(value, Tensor) and value.is_cuda:
#
# File ~/.conda/envs/lab/lib/python3.13/site-packages/torch_geometric/data/collate.py:203, in _collate(key, values, data_list, stores, increment)
#     200         shape[cat_dim] = int(slices[-1])
#     201     out = elem.new(storage).resize_(*shape)
# --> 203 value = torch.cat(values, dim=cat_dim or 0, out=out)
#     205 if increment and isinstance(value, Index) and values[0].is_sorted:
#     206     # Check whether the whole `Index` is sorted:
#     207     if (value.diff() >= 0).all():
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 1280 but got size 1992 for tensor number 3 in the list.

# %%
data.batch
# Out:
# tensor([0, 0, 0,  ..., 3, 3, 3])
